# %% [markdown]
# # ETL Notebook
# Simple ETL using DuckDB and Pandas.

# %%
import pandas as pd
import duckdb
taxi_df = pd.read_csv('../sample_data/taxi_sample.csv')
con = duckdb.connect(':memory:')
con.register('taxi', taxi_df)
con.execute('SELECT * FROM taxi LIMIT 5').df()
